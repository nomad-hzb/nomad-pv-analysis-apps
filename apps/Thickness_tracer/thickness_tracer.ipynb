# %%
# %load_ext autoreload
# %autoreload 2

from app import initialize_ui
from IPython.display import HTML, display

from hysprint_utils.access_token import log_notebook_usage

# %%
display(HTML("<script>document.title='NOMAD Thickness Tracer'</script>"))
log_notebook_usage()

display(initialize_ui())
