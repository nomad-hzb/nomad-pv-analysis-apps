# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import AbsPlApp
from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE

MANUAL_FILE = "eqe_manual.md"  # set to None if the file does not exist

# %%
token = get_token(f"{URL_BASE}{API_ENDPOINT}")
log_notebook_usage()

app = AbsPlApp(URL_BASE, API_ENDPOINT, token, manual_file=MANUAL_FILE)
app.display()
# Out:
# VBox(children=(VBox(children=(ToggleButton(value=False, description='Manual'), Output())), VBox(children=(VBox…
