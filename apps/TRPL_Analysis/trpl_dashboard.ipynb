# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import TRPLApp
from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE

MANUAL_FILE = None

# %%
token = get_token(f"{URL_BASE}{API_ENDPOINT}")
log_notebook_usage()

app = TRPLApp(URL_BASE, API_ENDPOINT, token, manual_file=MANUAL_FILE)
app.display()
# Out:
# VBox(children=(HTML(value='<p>Select from all 327 available batches, or filter to those with TRPL data:</p>'),…
# VBox(children=(Output(), Output()))
