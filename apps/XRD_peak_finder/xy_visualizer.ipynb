# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import XRDApp
from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE

MANUAL_FILE = None  # or "eqe_manual.md"

# %%
token = get_token(f"{URL_BASE}{API_ENDPOINT}")
log_notebook_usage()

app = XRDApp(URL_BASE, API_ENDPOINT, token, manual_file=MANUAL_FILE)
app.display()
