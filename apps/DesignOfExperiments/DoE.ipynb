# %%
import hysprint_utils.access_token as access_token

access_token.log_notebook_usage()

# %%
from IPython.display import display
from app import DoEApplication

app = DoEApplication()
display(app.main_interface)
