# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import EQEApp
from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE

MANUAL_FILE = None

token = get_token(f"{URL_BASE}{API_ENDPOINT}")
log_notebook_usage()

app = EQEApp(URL_BASE, API_ENDPOINT, token, manual_file=MANUAL_FILE)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
app.display()
# Out:
# VBox(children=(Button(button_style='warning', description='Load demo data', icon='database', style=ButtonStyle…
