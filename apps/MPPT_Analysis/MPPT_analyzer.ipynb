# %%
from hysprint_utils.access_token import log_notebook_usage

log_notebook_usage()

# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

import plotly.io as pio
from app_controller import create_mppt_app
from IPython.display import HTML, display
from plotly.offline import init_notebook_mode

from hysprint_utils.access_token import get_token
from hysprint_utils.config import API_ENDPOINT, URL_BASE

init_notebook_mode(connected=True)
pio.renderers.default = "notebook"
display(HTML("<script>document.title='NOMAD MPPT Analyzer'</script>"))

token = get_token(f"{URL_BASE}{API_ENDPOINT}")
app = create_mppt_app(token)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <script>document.title='NOMAD MPPT Analyzer'</script>
# ...
