# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from app import initialize_ui, page_title
from IPython.display import HTML, display

from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE

VARIANT = "main"

# %%
plt.ioff()
# %matplotlib widget

URL_API = URL_BASE + API_ENDPOINT
display(HTML(f"<script>document.title='{page_title(VARIANT)}'</script>"))
log_notebook_usage()

display(initialize_ui(URL_API, get_token(URL_API), VARIANT))
