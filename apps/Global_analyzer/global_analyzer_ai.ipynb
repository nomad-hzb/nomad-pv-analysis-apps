# %%
from hysprint_utils import access_token

access_token.log_notebook_usage()

# %%
from ai_summary import AISummaryPanel
from app import SampleDataExplorer
from app_secrets import BLABLADOR_API_KEY

from hysprint_utils import access_token
from hysprint_utils.config import API_ENDPOINT, URL_BASE

_url = f"{URL_BASE}{API_ENDPOINT}"
NOMAD_TOKEN = access_token.get_token(_url)

analyzer = SampleDataExplorer(_url, NOMAD_TOKEN)
analyzer.display()

ai_panel = AISummaryPanel(analyzer, BLABLADOR_API_KEY)
display(ai_panel.widget)
