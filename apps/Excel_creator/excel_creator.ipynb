# %%
from IPython.display import HTML, display
from voila_experiment_app import create_experiment_app

from hysprint_utils.access_token import log_notebook_usage

display(HTML("<script>document.title='NOMAD Excel Creator'</script>"))
log_notebook_usage()

# %%
app = create_experiment_app()
