# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import NMRPlotterApp
from hysprint_utils.access_token import get_token, log_notebook_usage
from hysprint_utils.config import API_ENDPOINT, URL_BASE
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
token = get_token(f"{URL_BASE}{API_ENDPOINT}")
log_notebook_usage()

app = NMRPlotterApp(URL_BASE, API_ENDPOINT, token)
app.display()
# Out:
# VBox(children=(VBox(children=(HTML(value='<p>Select from all 327 available batches, or filter to batches with …
