# %% [markdown]
# # Peak Analyzer
#
# Interactive application for analyzing spectral and diffraction data with peak detection and fitting.

# %%
from IPython.display import HTML, display

display(HTML("<script>document.title='NOMAD Peak Explorer'</script>"))

from gui_layouts import PLAnalysisApp  # noqa: E402

app = PLAnalysisApp()
app.display_app()
