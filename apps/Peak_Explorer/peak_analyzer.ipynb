# %% [markdown]
# # Peak Analyzer
#
# Interactive application for analyzing spectral and diffraction data with peak detection and fitting.

# %%
from gui_layouts import PLAnalysisApp

app = PLAnalysisApp()
app.display_app()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from gui_layouts import PLAnalysisApp
#       3 app = PLAnalysisApp()
#       4 app.display_app()
#
# File ~/uploads/analysis_apps_restructuring-WxUahazkSNy-bSE9GaZyZQ/apps/Peak_Explorer/gui_layouts.py:15
#      13 import config
#      14 from utils import debug_print
# ---> 15 from data_manager import DataManager, sanitize_float
#      17 import warnings
#      18 warnings.filterwarnings('ignore', message='Using UFloat objects with std_dev==0')
#
# File ~/uploads/analysis_apps_restructuring-WxUahazkSNy-bSE9GaZyZQ/apps/Peak_Explorer/data_manager.py:18
#      16 if utils_dir not in sys.path:
#      17     sys.path.insert(0, utils_dir)
# ---> 18 import access_token
#      20 # Log notebook usage
#      21 access_token.log_notebook_usage()
#
# ModuleNotFoundError: No module named 'access_token'
