# %%
from app import setup_app
from IPython.display import HTML, display

from hysprint_utils.access_token import log_notebook_usage

display(HTML("<script>document.title='NOMAD Bitmap Maker'</script>"))
log_notebook_usage()

# %%
app = setup_app()
display(app)
