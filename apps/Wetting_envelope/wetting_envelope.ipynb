# %%
from hysprint_utils.access_token import log_notebook_usage

log_notebook_usage()

# %%
# %load_ext autoreload
# %autoreload 2

from app import WettingEnvelopeApp

app = WettingEnvelopeApp()
app.display()
