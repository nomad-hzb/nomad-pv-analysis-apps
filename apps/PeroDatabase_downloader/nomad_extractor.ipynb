# %%
from IPython.display import HTML, display

from hysprint_utils.access_token import log_notebook_usage

display(HTML("<script>document.title='NOMAD PeroDatabase Downloader'</script>"))
log_notebook_usage()

# %%
from app import NomadExtractorApp

NomadExtractorApp().launch()
