# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import HansenApp
from hysprint_utils.access_token import log_notebook_usage

# Paths relative to this notebook
DB_PATH = "db.csv"
INKS_PATH = "PlottedInks.xlsx"

# %%
log_notebook_usage()

app = HansenApp(db_path=DB_PATH, inks_path=INKS_PATH)
app.display()
# Out:
# Output()
# VBox(children=(HTML(value="<h2 style='text-align:center;margin-bottom:4px'>Hansen Solubility Parameter Tool Su…
