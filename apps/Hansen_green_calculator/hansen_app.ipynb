# %%
# %matplotlib ipympl
# %load_ext autoreload
# %autoreload 2

from app import HansenApp
from IPython.display import HTML, display

from hysprint_utils.access_token import log_notebook_usage

# Paths relative to this notebook
DB_PATH = "db.csv"
INKS_PATH = "PlottedInks.xlsx"

# %%
display(HTML("<script>document.title='NOMAD Hansen Green Calculator'</script>"))
log_notebook_usage()

app = HansenApp(db_path=DB_PATH, inks_path=INKS_PATH)
app.display()
